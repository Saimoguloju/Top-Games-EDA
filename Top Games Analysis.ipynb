# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("games_dataset.csv")

# %%
df.head()
# Out:
#                       Game Name       Genre         Platform  Release Year  \
# 0     Sekiro: Shadows Die Twice      Sports  Nintendo Switch          2014
# 1                       Control      Puzzle  Nintendo Switch          2000
# 2                      Among Us    Strategy  Nintendo Switch          2007
# 3  Call of Duty: Modern Warfare     Stealth      PlayStation          2005
# 4             League of Legends  Simulation               PC          2021
#
#    User Rating
# 0     9.654719
# 1     3.457386
# 2     5.367622
# 3     1.240325
# 4     3.535476

# %%
df.tail()
# Out:
#                                     Game Name       Genre     Platform  \
# 4995  The Legend of Zelda: Breath of the Wild      Sports           PC
# 4996                Assassin's Creed Valhalla     Stealth       Mobile
# 4997             Fall Guys: Ultimate Knockout      Sports       Mobile
# 4998                            Borderlands 3  Platformer         Xbox
# 4999         Counter-Strike: Global Offensive      Action  PlayStation
#
#       Release Year  User Rating
# 4995          2013     6.352838
# 4996          2020     1.852730
# 4997          2021     5.268067
# 4998          2018     4.558510
# 4999          2022     3.443231

# %%
df.shape
# Out:
# (5000, 5)

# %%
df.columns
# Out:
# Index(['Game Name', 'Genre', 'Platform', 'Release Year', 'User Rating'], dtype='object')

# %%
df.dtypes
# Out:
# Game Name        object
# Genre            object
# Platform         object
# Release Year      int64
# User Rating     float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Game Name     5000 non-null   object
#  1   Genre         5000 non-null   object
#  2   Platform      5000 non-null   object
#  3   Release Year  5000 non-null   int64
#  4   User Rating   5000 non-null   float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 195.4+ KB

# %%
df.isnull().sum()
# Out:
# Game Name       0
# Genre           0
# Platform        0
# Release Year    0
# User Rating     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#        Release Year  User Rating
# count   5000.000000  5000.000000
# mean    2011.375400     5.524913
# std        6.943984     2.598429
# min     2000.000000     1.005878
# 25%     2005.000000     3.260596
# 50%     2011.000000     5.574233
# 75%     2017.000000     7.802727
# max     2023.000000     9.996196

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['User Rating'], bins=20, kde=True)
plt.title('Distribution of User Ratings')
plt.xlabel('User Rating')
plt.ylabel('Frequency')
plt.savefig("Distribution of User Ratings.png")
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.countplot(y=df['Genre'], order=df['Genre'].value_counts().index, palette="viridis")
plt.title('Count of Games per Genre')
plt.xlabel('Count')
plt.ylabel('Genre')
plt.savefig("Count of Games per Genre.png")
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.countplot(y=df['Platform'], order=df['Platform'].value_counts().index, palette="viridis")
plt.title('Count of Games per Platform')
plt.xlabel('Count')
plt.ylabel('Platform')
plt.savefig("Count of Games per Platform.png")
plt.show()

# %%
plt.figure(figsize=(12, 8))
avg_rating_genre = df.groupby('Genre')['User Rating'].mean().sort_values()
sns.barplot(x=avg_rating_genre, y=avg_rating_genre.index, palette="viridis")
plt.title('Average User Rating by Genre')
plt.xlabel('Average User Rating')
plt.ylabel('Genre')
plt.savefig("Average User Rating by Genre.png")
plt.show()

# %%
plt.figure(figsize=(12, 8))
avg_rating_platform = df.groupby('Platform')['User Rating'].mean().sort_values()
sns.barplot(x=avg_rating_platform, y=avg_rating_platform.index, palette="viridis")
plt.title('Average User Rating by Platform')
plt.xlabel('Average User Rating')
plt.ylabel('Platform')
plt.savefig("Average User Rating by Platform.png")
plt.show()

# %%
games_per_year = df['Release Year'].value_counts().sort_index()
plt.figure(figsize=(12, 6))
sns.lineplot(x=games_per_year.index, y=games_per_year.values, marker='o')
plt.title('Number of Games Released per Year')
plt.xlabel('Release Year')
plt.ylabel('Count')
plt.grid(True)
plt.savefig("Number of Games Released per Year.png")
plt.show()

# %%
average_rating_per_year = df.groupby('Release Year')['User Rating'].mean()
plt.figure(figsize=(12, 6))
sns.lineplot(x=average_rating_per_year.index, y=average_rating_per_year.values, marker='o', color='r')
plt.title('Average Rating per Year')
plt.xlabel('Release Year')
plt.ylabel('Average User Rating')
plt.grid(True)
plt.savefig("Average Rating per Year")
plt.show()
